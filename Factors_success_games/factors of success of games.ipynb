# %% [markdown]
# # Сборный проект по определению факторов успеха игр

# %% [markdown]
# **Описание проекта:**
#
#   Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# **План проекта:**
# - Открыть файл с данными и изучить общую информацию. Путь к файлу: /datasets/games.csv
# - Подготовить данные к анализу
# - Провести исследовательский анализ данных
# - Составить портрет пользователя каждого региона
# - Проверить гипотезы
# - Написать общий вывод

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Подключаем-библиотеки" data-toc-modified-id="Подключаем-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Подключаем библиотеки</a></span></li><li><span><a href="#Открываем-csv-файл" data-toc-modified-id="Открываем-csv-файл-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Открываем csv файл</a></span></li><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Общая информация</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-названия-столбцов" data-toc-modified-id="Замена-названия-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Замена названия столбцов</a></span></li><li><span><a href="#Работа-с-пропусками" data-toc-modified-id="Работа-с-пропусками-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Работа с пропусками</a></span><ul class="toc-item"><li><span><a href="#Колонки-имя-и-жанра" data-toc-modified-id="Колонки-имя-и-жанра-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Колонки имя и жанра</a></span></li><li><span><a href="#Колонка-год-выпуска" data-toc-modified-id="Колонка-год-выпуска-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Колонка год выпуска</a></span></li><li><span><a href="#Колонка-оценка-критиков" data-toc-modified-id="Колонка-оценка-критиков-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Колонка оценка критиков</a></span></li><li><span><a href="#Колонка-оценка-пользователей" data-toc-modified-id="Колонка-оценка-пользователей-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Колонка оценка пользователей</a></span></li><li><span><a href="#Колонка-рейтинг" data-toc-modified-id="Колонка-рейтинг-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Колонка рейтинг</a></span></li></ul></li><li><span><a href="#Преобразовываем-данные-в-нужный-тип" data-toc-modified-id="Преобразовываем-данные-в-нужный-тип-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Преобразовываем данные в нужный тип</a></span><ul class="toc-item"><li><span><a href="#Колонку-с-годом-выпуска-в-int---целые-числа" data-toc-modified-id="Колонку-с-годом-выпуска-в-int---целые-числа-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Колонку с годом выпуска в <code>int</code> - целые числа</a></span></li><li><span><a href="#Колонку-с-оценкой-критиков-в-int---целые-числа" data-toc-modified-id="Колонку-с-оценкой-критиков-в-int---целые-числа-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Колонку с оценкой критиков в <code>int</code> - целые числа</a></span></li><li><span><a href="#Колонку-с-оценкой-пользователей-в-float----числа-с-плавающей-точкой" data-toc-modified-id="Колонку-с-оценкой-пользователей-в-float----числа-с-плавающей-точкой-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Колонку с оценкой пользователей в <code>float</code> -  числа с плавающей точкой</a></span></li></ul></li><li><span><a href="#Проверка-на-дубликаты" data-toc-modified-id="Проверка-на-дубликаты-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Проверка на дубликаты</a></span></li><li><span><a href="#Посчитаем-суммарные-продажи-во-всех-регионах-и-запишем-их-в-отдельный-столбец." data-toc-modified-id="Посчитаем-суммарные-продажи-во-всех-регионах-и-запишем-их-в-отдельный-столбец.-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец.</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Сколько-игр-выпускалось-в-разные-годы" data-toc-modified-id="Сколько-игр-выпускалось-в-разные-годы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Сколько игр выпускалось в разные годы</a></span></li><li><span><a href="#Как-менялись-продажи-по-платформам" data-toc-modified-id="Как-менялись-продажи-по-платформам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Как менялись продажи по платформам</a></span></li><li><span><a href="#Данные-за-актуальный-период" data-toc-modified-id="Данные-за-актуальный-период-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Данные за актуальный период</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ." data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.</a></span></li><li><span><a href="#График-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам" data-toc-modified-id="График-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>График «ящик с усами» по глобальным продажам игр в разбивке по платформам</a></span></li><li><span><a href="#Влияние-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков" data-toc-modified-id="Влияние-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Влияние на продажи внутри одной популярной платформы отзывы пользователей и критиков</a></span></li><li><span><a href="#Общее-распределение-игр-по-жанрам." data-toc-modified-id="Общее-распределение-игр-по-жанрам.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Общее распределение игр по жанрам.</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-каждого-региона" data-toc-modified-id="Портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-(топ-5)" data-toc-modified-id="Самые-популярные-платформы-(топ-5)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Самые популярные платформы (топ-5)</a></span></li><li><span><a href="#Самые-популярные-жанры-(топ-5)" data-toc-modified-id="Самые-популярные-жанры-(топ-5)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Самые популярные жанры (топ-5)</a></span></li><li><span><a href="#Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?" data-toc-modified-id="Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияет ли рейтинг ESRB на продажи в отдельном регионе?</a></span></li></ul></li><li><span><a href="#Проверка-гипотезы" data-toc-modified-id="Проверка-гипотезы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотезы</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a></span></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные" data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные</a></span></li></ul></li><li><span><a href="#Общий-вывод:" data-toc-modified-id="Общий-вывод:-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод:</a></span></li></ul></div>

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ### Подключаем библиотеки

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
import numpy as np

# %% [markdown]
# ### Открываем csv файл

# %%
data = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# ### Общая информация

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Получили таблицу из 11 колонок (5 текстовых и 6 числовых с плавающей точкой) и 16715 строк.
#
# Данные за 2016 год могут быть неполными. Описание данных:
# - **Name** — название игры
# - **Platform** — платформа
# - **Year_of_Release** — год выпуска
# - **Genre** — жанр игры
# - **NA_sales** — продажи в Северной Америке (миллионы проданных копий)
# - **EU_sales** — продажи в Европе (миллионы проданных копий)
# - **JP_sales** — продажи в Японии (миллионы проданных копий)
# - **Other_sales** — продажи в других странах (миллионы проданных копий)
# - **Critic_Score** — оценка критиков (максимум 100)
# - **User_Score** — оценка пользователей (максимум 10)
# - **Rating** — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Есть пропуски в колонках: `Year_of_Release`, `Critic_Score`, `User_Score` и `Rating`, а также парочка в Name и Genre

# %%
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Замена названия столбцов

# %%
data.columns = data.columns.str.lower()

# %% [markdown]
# Перевели все названия колонок в нижний регистр

# %% [markdown]
# ### Работа с пропусками

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# #### Колонки имя и жанра

# %%
data[data['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %%
data = data.drop([659, 14244])

# %% [markdown]
# #### Колонка год выпуска

# %%
data['year_of_release'].isna().sum()
# Out:
# 269

# %%
data['year_of_release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %%
data = data.dropna(subset=['year_of_release'])

# %% [markdown]
# #### Колонка оценка критиков

# %%
data['critic_score'].isna().sum()
# Out:
# 8461

# %% [markdown]
# 8578

# %%
data['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %%
data['critic_score'] = data['critic_score'].fillna(0)

# %% [markdown]
# #### Колонка оценка пользователей

# %%
data['user_score'].isna().sum()
# Out:
# 6605

# %%
data['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
data['user_score'] = data['user_score'].fillna(0)

# %% [markdown]
# #### Колонка рейтинг

# %%
data['rating'].isna().sum()
# Out:
# 6676

# %%
data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# - **EC(«Early childhood»)** - для детей младшего возраста. Подходит для детей от 3 лет, неприемлемое содержание отсутствует.
# - **E(«Everyone»)** - для всех возрастных категорий(ранее с 6 лет). Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера. Первоначально **K-A(«Kids to Adults»)**
# - **E 10+(«Everyone 10 and older»)** - для лиц старше 10 лет. Проекты с данным рейтингом могут содержать больше мультипликационного или мягкого насилия, или несколько откровенные сцены, или минимальное количество крови.
# - **T(«Teen»)** - для лиц старше 13 лет. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики.
# - **M(«Mature»)** - для лиц младше 17 лет. Проекты с данным рейтингом могут содержать жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику.
# - **AO(«Adults Only 18+»)** - для взрослых старше 18 лет. Продукты из данной категории могут содержать длительные сцены жестокого насилия и/или очень откровенное сексуальное содержимое.
# - **RP(«Rating Pending»)** - Продукт был отправлен в ESRB и ожидает присвоения рейтинга.
#
# E и K-A одно и тоже, можно перезаписать всё как Е

# %%
data['rating'] = data['rating'].fillna('unknown')

# %%
data.isna().sum() #проверяем
# Out:
# name               0
# platform           0
# year_of_release    0
# genre              0
# na_sales           0
# eu_sales           0
# jp_sales           0
# other_sales        0
# critic_score       0
# user_score         0
# rating             0
# dtype: int64

# %% [markdown]
# **Вывод:** Две пустые строки в названиях и в жанрах были удалены.
#
# Все пропуски заменили на "0", для удобства дальнейшей работы с числами и арифметических действий
#
# `'tbd'` - эта аббревиатура расшифровывается как - "To Be Determined", то есть "Будет определено", в данном случае очки пользователей неизвестны
#
# Существуют разные системы рейтинга, в России - это RARS(Russian Age Rating System), в Европе - PEGI(Pan European Game Information), в Японии - CERO(Computer Entertainment Rating Organization), здесь представлена Система ESRB(Entertainment Software Rating Board) - для США, Мексики и Канады.
#
# Все пропуски в рейтинге заменили на *unknown*

# %% [markdown]
# ### Преобразовываем данные в нужный тип

# %% [markdown]
# #### Колонку с годом выпуска в `int` - целые числа

# %%
data['year_of_release'] = data['year_of_release'].astype('int')

# %% [markdown]
# #### Колонку с оценкой критиков в `int` - целые числа

# %%
data['critic_score'] = data['critic_score'].astype('int')

# %% [markdown]
# #### Колонку с оценкой пользователей в `float` -  числа с плавающей точкой

# %%
data['user_score'] = pd.to_numeric(data['user_score'], errors='coerce')

# %%
data['user_score'] = data['user_score'].fillna(0)

# %% [markdown]
# ### Проверка на дубликаты

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['name'].duplicated().sum()
# Out:
# 5018

# %%
data['name'].value_counts()
# Out:
# Need for Speed: Most Wanted    12
# FIFA 14                         9
# LEGO Marvel Super Heroes        9
# Ratatouille                     9
# Cars                            8
#                                ..
# Rumble Roses                    1
# Battle Stations                 1
# WorldShift                      1
# Battlefield 2                   1
# Backyard Soccer                 1
# Name: name, Length: 11426, dtype: int64

# %%
data[data['name'] == 'Need for Speed: Most Wanted']
# Out:
#                               name platform  year_of_release   genre  \
# 253    Need for Speed: Most Wanted      PS2             2005  Racing
# 523    Need for Speed: Most Wanted      PS3             2012  Racing
# 1190   Need for Speed: Most Wanted     X360             2012  Racing
# 1591   Need for Speed: Most Wanted     X360             2005  Racing
# 1998   Need for Speed: Most Wanted       XB             2005  Racing
# 2048   Need for Speed: Most Wanted      PSV             2012  Racing
# 3581   Need for Speed: Most Wanted       GC             2005  Racing
# 5972   Need for Speed: Most Wanted       PC             2005  Racing
# 6273   Need for Speed: Most Wanted     WiiU             2013  Racing
# 6410   Need for Speed: Most Wanted       DS             2005  Racing
# 6473   Need for Speed: Most Wanted      GBA             2005  Racing
# 11715  Need for Speed: Most Wanted       PC             2012  Racing
#
# ...

# %%
data['platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
data.info() # проверяем
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     16444 non-null  int64
#  9   user_score       16444 non-null  float64
#  10  rating           16444 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.5+ MB

# %%
data.loc[data.duplicated(subset=['name', 'platform', 'year_of_release'])]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 16230  Madden NFL 13      PS3             2012  Sports       0.0      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating
# 16230       0.0          0.0            83         5.5      E

# %%
data[data['name'] == 'Madden NFL 13']
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 507    Madden NFL 13     X360             2012  Sports      2.53      0.15
# 604    Madden NFL 13      PS3             2012  Sports      2.11      0.22
# 3986   Madden NFL 13      Wii             2012  Sports      0.47      0.00
# 5887   Madden NFL 13      PSV             2012  Sports      0.28      0.00
# 7066   Madden NFL 13     WiiU             2012  Sports      0.21      0.00
# 16230  Madden NFL 13      PS3             2012  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating
# 507         0.0         0.17            81         5.8      E
# 604         0.0         0.23            83         5.5      E
# 3986        0.0         0.03             0         7.3      E
# 5887        0.0         0.02            63         7.3      E
# 7066        0.0         0.02            75         6.7      E
# 16230       0.0         0.00            83         5.5      E

# %%
data.query('platform == "GEN" & year_of_release == 1993.0')
# Out:
#                                                     name platform  \
# 7885                                    Shining Force II      GEN
# 8893                             Super Street Fighter II      GEN
# 11986                            Ecco: The Tides of Time      GEN
# 12098  Street Fighter II': Special Champion Edition (...      GEN
# 12264                                  Streets of Rage 3      GEN
# 12984                                    Dynamite Headdy      GEN
# 13343                                       Beyond Oasis      GEN
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 7885              1993      Strategy       0.0       0.0      0.19
# 8893              1993      Fighting       0.0       0.0      0.15
# 11986             1993     Adventure       0.0       0.0      0.07
# 12098             1993        Action       0.0       0.0      0.07
# 12264             1993        Action       0.0       0.0      0.07
# ...

# %%
data = data.drop_duplicates(subset=['name', 'platform', 'year_of_release', 'genre'], keep='first')

# %% [markdown]
# ### Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец.

# %%
data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']

# %%
data.head(10)
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0     41.36     28.96      3.77         8.45            76         8.0
# ...

# %% [markdown]
# **Вывод:** Все данные привели к нужному типу. Получилось 11 колонок (4 текстовых, 5 числа с плавающей точкой и 2 с целыми числами) по 16713 строк, пустых полей нет.
#
# Ноль будет значить, что данные остутствуют. Причины могут быть разные: не корректно были собраны данные, либо они отсутсвовали в источниках или же просто не были внесены, человеский фактор.
#
# Есть дубликаты в названиях, но это одна игра выпущенная на разных платформах в разные года.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Сколько игр выпускалось в разные годы

# %%
(data['year_of_release'].value_counts().sort_index()
 .plot(kind='bar', figsize=(13,4), fontsize=16)
)
plt.title('Выпуск игр по годам', fontsize=16)
plt.ylabel('Количество', fontsize=16)
plt.xlabel('Год', fontsize=16);

# %%
data['year_of_release'].value_counts().describe()
# Out:
# count      37.000000
# mean      444.405405
# std       451.591535
# min         9.000000
# 25%        36.000000
# 50%       338.000000
# 75%       762.000000
# max      1427.000000
# Name: year_of_release, dtype: float64

# %% [markdown]
# На вопрос важны ли все данные? До 90-х индустрии игр как таковой не было, и вообще компьютеры только разрабатывались, так что этот период можно сразу отбросить, с 91 до 93 начинается развитие и дальнейший рост. В 2002 видно большой скачок, появилось много игр, популярность набирает обороты. Пик развития приходится на 2008-2009 года. Потом идет спад и в 2012 видимо наступил кризис, или начало чего-то нового. А для прогноза на 2017 год, лучше брать последние года, т.к. индустрия развивается, "железо", игры устаревают, как и те кто в них играл.

# %% [markdown]
# ### Как менялись продажи по платформам

# %%
(data.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(by='total_sales', ascending=False)
 .plot(kind='bar', figsize=(15,4), fontsize=16)
)
plt.title('Продажи по платформам', fontsize=16)
plt.ylabel('Сумма продаж', fontsize=16)
plt.xlabel('Платформа', fontsize=16);

# %%
(data.query('platform in ["DS", "PS", "PS2", "PS3", "Wii", "X360"]')
 .plot(kind='scatter', x='year_of_release', y='platform', figsize=(15,4), fontsize=16, grid=True)
)
plt.title('Распределение платформ по годам', fontsize=16)
plt.ylabel('Платформа', fontsize=16)
plt.xlabel('Год', fontsize=16);

# %% [markdown]
# Рассмотрев популярные модели платформы "PS", можно сказать, что срок появления новых и исчезновение старых платформ 7 лет.

# %% [markdown]
# ### Данные за актуальный период

# %%
relevant_data = data.query('year_of_release > 2013')
relevant_data
# Out:
#                                             name platform  year_of_release  \
# 31                     Call of Duty: Black Ops 3      PS4             2015
# 42                            Grand Theft Auto V      PS4             2014
# 47     Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 77                                       FIFA 16      PS4             2015
# 87                  Star Wars Battlefront (2015)      PS4             2015
# ...                                          ...      ...              ...
# 16703                           Strawberry Nauts      PSV             2016
# 16707                           Aiyoku no Eustia      PSV             2014
# 16710              Samurai Warriors: Sanada Maru      PS3             2016
# 16712                    Haitaka no Psychedelica      PSV             2016
# 16714                        Winning Post 8 2016      PSV             2016
#
# ...

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %%
(relevant_data.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(by='total_sales', ascending=False)
 .plot(kind='bar', figsize=(15,4), fontsize=16)
)
plt.title('Продажи по платформам', fontsize=16)
plt.ylabel('Сумма продаж', fontsize=16)
plt.xlabel('Платформа', fontsize=16);

# %%
(relevant_data.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='median')
.plot(style='-o', figsize=(15,4), fontsize=16, grid=True)
)
plt.title('Продажи по платформам', fontsize=16)
plt.ylabel('Сумма продаж', fontsize=16)
plt.xlabel('Год', fontsize=16);

# %% [markdown]
# Лидеры по продажам: "PS4", "XOne", но у них продажи сильно упали, за данный период. Видимо это связано с падением "новизны", т.е. продукт вышел на рынок, сразу раскупили, а затем продажи естественно снижаются.  "3DS" и "WiiU" тоже продаются, снижение продаж минимальное. А вот рост продаж наблюдается у "Wii" и "PS3", но тут наоборот, были низкие продажи, т.к. это устаревающие платформы.

# %% [markdown]
# ### График «ящик с усами» по глобальным продажам игр в разбивке по платформам

# %%
sns.boxplot(y="platform", x="total_sales", data=relevant_data)
sns.figsize=(16,10);

# %%
relevant_data['total_sales'].describe()
# Out:
# count    1689.000000
# mean        0.431883
# std         1.056109
# min         0.010000
# 25%         0.030000
# 50%         0.100000
# 75%         0.350000
# max        14.630000
# Name: total_sales, dtype: float64

# %%
relevant_data_less = relevant_data.query('total_sales < 0.5')

# %%
boxplot = sns.boxplot(y="platform", x="total_sales", data=relevant_data_less, showfliers=False)
boxplot.set_title('Глобальные продажи по платформам', fontsize = 16)
boxplot.set_xlabel('Продажи', fontsize = 14)
boxplot.set_ylabel('Платформы', fontsize = 14);

# %% [markdown]
# Медианные значения по продажам игр у всех платформ меньше 100 тыс. копий, самые высокие у WiiU, Wii и X360, а также PS4, можно еще добавить XOne. У них же и самые большие "усы".

# %% [markdown]
# ### Влияние на продажи внутри одной популярной платформы отзывы пользователей и критиков

# %%
top_platform_xone = relevant_data.query('platform == "XOne" and critic_score != 0 and user_score != 0')

# %%
top_platform_xone.plot(kind='scatter', x='critic_score', y='total_sales', figsize=(15,4), fontsize=16)
plt.title('Влияние на продажи отзывов критиков "XOne"', fontsize=16)
plt.ylabel('Продажи', fontsize=16)
plt.xlabel('Отзывы критиков', fontsize=16);

# %%
top_platform_xone['total_sales'].corr(top_platform_xone['critic_score']).round(2)
# Out:
# 0.42

# %%
top_platform_xone.plot(kind='scatter', x='user_score', y='total_sales', figsize=(15,4), fontsize=16)
plt.title('Влияние на продажи отзывов пользователей "XOne"', fontsize=16)
plt.ylabel('Продажи', fontsize=16)
plt.xlabel('Отзывы пользователей', fontsize=16);

# %%
top_platform_xone['total_sales'].corr(top_platform_xone['user_score']).round(2)
# Out:
# -0.09

# %% [markdown]
# На платформе "XOne" существует связь продажи от отзывов критиков, а вот с пользователями связи нет.

# %%
top_platform_PS4 = relevant_data.query('platform == "PS4" and critic_score != 0 and user_score != 0')

# %%
top_platform_PS4.plot(kind='scatter', x='critic_score', y='total_sales', figsize=(15,4), fontsize=16)
plt.title('Влияние на продажи отзывов критиков "PS4"', fontsize=16)
plt.ylabel('Продажи', fontsize=16)
plt.xlabel('Отзывы критиков', fontsize=16);

# %%
top_platform_PS4['total_sales'].corr(top_platform_PS4['critic_score']).round(2)
# Out:
# 0.4

# %%
top_platform_PS4.plot(kind='scatter', x='user_score', y='total_sales', figsize=(15,4), fontsize=16)
plt.title('Влияние на продажи отзывов пользователей "PS4"', fontsize=16)
plt.ylabel('Продажи', fontsize=16)
plt.xlabel('Отзывы пользователей', fontsize=16);

# %%
top_platform_PS4['total_sales'].corr(top_platform_PS4['user_score']).round(2)
# Out:
# -0.04

# %%
top_platform_3DS = relevant_data.query('platform == "3DS" and critic_score != 0 and user_score != 0')

# %%
top_platform_3DS.plot(kind='scatter', x='critic_score', y='total_sales', figsize=(15,4), fontsize=16)
plt.title('Влияние на продажи отзывов критиков "3DS"', fontsize=16)
plt.ylabel('Продажи', fontsize=16)
plt.xlabel('Отзывы критиков', fontsize=16);

# %%
top_platform_3DS['total_sales'].corr(top_platform_3DS['critic_score']).round(2)
# Out:
# 0.28

# %%
top_platform_3DS.plot(kind='scatter', x='user_score', y='total_sales', figsize=(15,4), fontsize=16)
plt.title('Влияние на продажи отзывов пользователей "3DS"', fontsize=16)
plt.ylabel('Продажи', fontsize=16)
plt.xlabel('Отзывы пользователей', fontsize=16);

# %%
top_platform_3DS['total_sales'].corr(top_platform_3DS['user_score']).round(2)
# Out:
# 0.28

# %% [markdown]
# Взяв основные топовые платформы "PS4", "XOne" и оценив влияние отзывов критиков и пользователей на продажи, можно сказать, что у критиков есть одинаково небольшое положительное влияние, а вот отзывы пользователей, есть влияние только на платформе "3DS", "WiiU".

# %% [markdown]
# ### Общее распределение игр по жанрам.

# %%
(relevant_data.pivot_table(index='genre', values='total_sales', aggfunc='sum')
 .sort_values(by='total_sales', ascending=False)
 .plot(kind='bar', figsize=(15,4), fontsize=16, rot=45)
)
plt.title('Продажи по жанрам', fontsize=16)
plt.ylabel('Сумма продаж', fontsize=16)
plt.xlabel('Жанры', fontsize=16);

# %%
genre_sales = relevant_data.pivot_table(index='genre', values='total_sales', aggfunc=['sum', 'count', 'mean'])
# genre_sales['ratio'] = genre_sales['sum']['total_sales'] / genre_sales['count']['total_sales']
col = ["sum", "count", "ratio"]
genre_sales.columns = col
genre_sales.sort_values(by='ratio', ascending=False)
# Out:
#                  sum  count     ratio
# genre
# Shooter       170.94    128  1.335469
# Sports        109.48    161  0.680000
# Platform       18.09     38  0.476053
# Fighting       28.22     60  0.470333
# Role-Playing  101.44    221  0.459005
# Racing         27.52     69  0.398841
# Misc           37.55    113  0.332301
# Action        199.36    619  0.322068
# Simulation     13.13     44  0.298409
# Puzzle          2.21     14  0.157857
# Strategy        3.96     37  0.107027
# Adventure      17.55    185  0.094865

# %% [markdown]
# Самые продаваемые жанры: Шутер - прибыльный, Экшн, но прибыльный ли он? Если посмотреть соотношение количества и прибыли, только 32% окупаемости в сравнение с третьи - Спорт, менее популярнее и более прибыльнее. А если учитывать сколько затрат времени и ресурсов уходит на создание Шутера или Платформера.

# %% [markdown]
# ## Портрет пользователя каждого региона
#
# Определите для пользователя каждого региона (NA, EU, JP):

# %% [markdown]
# ### Самые популярные платформы (топ-5)

# %%
region_data = relevant_data.query('na_sales != 0 and eu_sales !=0 and jp_sales != 0')

# %%
top_platform = (region_data.pivot_table(index='platform', values=['na_sales','eu_sales','jp_sales'], aggfunc='sum')
.sort_values(by='na_sales', ascending=False))

# %%
(top_platform.plot(kind='pie', subplots=True, figsize=(15, 5), legend=False, 
                   autopct='%1.1f%%', textprops=dict(color="w"), pctdistance=.8))
plt.title('Популярность платформ в регионах', fontsize=16)
plt.legend(loc="best")
plt.axis('equal');

# %% [markdown]
# Топ 5 платформ для регионов:
#
# **NA:**: 1. "PS4", 2. "XOne", 3. "3DS", 4. "WiiU", 5. "PS3".
#
# **EU:**: 1. "PS4", 2. "PS3", 3. "XOne", 4. "3DS", 5. "WiiU".
#
# **JP:**: 1. "3DS", 2. "PS4", 3. "WiiU", 4. "PS3", 5. "PSV".
#
# Везде топ 5 почти схож, платформа "PS4" самая популярная по миру, особенно в Европе. На втором месте "XOne", больше в Америке, скорее из-за того, что она является производителем. В Японии же другая картина, хоть она и является производителем топовых моделей, больший рынок захватили более портативные платформы, видимо японцы предпочитают играть вне дома или нет мест для ТВ и консолей, а может все зависит от цены.

# %% [markdown]
# ### Самые популярные жанры (топ-5)

# %%
top_genre = (region_data.pivot_table(index='genre', values=['na_sales','eu_sales','jp_sales'], aggfunc='sum')
.sort_values(by='na_sales', ascending=False))

# %%
(top_genre.plot(kind='pie', subplots=True, autopct='%1.1f%%', figsize=(15, 8), legend=False)
)
plt.title('Популярность жанров в регионах', fontsize=16);

# %%
(region_data.pivot_table(index='genre', values=['na_sales','eu_sales','jp_sales'], aggfunc='sum')
 .sort_values(by='jp_sales', ascending=False)
 .plot(kind='bar', figsize=(13,4), fontsize=12, rot=45)
)
plt.title('Самые популярные жанры', fontsize=16)
plt.ylabel('Продажи', fontsize=14)
plt.xlabel('Жанр', fontsize=14);

# %% [markdown]
# Топ 5 жанров для регионов:
#
# **NA:**: 1. "Shooter", 2. "Action", 3. "Role-Playing", 4. "Sports", 5."Fighting".
#
# **EU:**: 1. "Shooter", 2. "Action", 3. "Sports", 4. "Role-Playing", 5. "Racing".
#
# **JP:**: 1. "Role-Playing", 2. "Action", 3. "Shooter", 4. "Fighting", 5. "Platform".
#
# Самый популярный жанр конечно же Шутер, где игрок полагается на координацию и реакцию. Войнушки все любят. На втором месте Экшн - это динамичный жанр со стремительно развивающимся сюжетом, обилием динамичных сцен, включая погони, перестрелки, поединки и т.п., больше в Японии преобладает РПГ, в котором игрок управляет одним или несколькими персонажами, каждый из которых описан набором численных характеристик, списком способностей и умений, приведших из настольных игр, где надо больше подумать.

# %% [markdown]
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
rating_sales = (region_data.pivot_table(index='rating', values=['na_sales','eu_sales','jp_sales'], aggfunc='sum')
.sort_values(by='na_sales', ascending=False))

# %%
rating_sales.plot(kind='pie', subplots=True, autopct='%1.1f%%', figsize=(15, 8), legend=False)
plt.title('Продажи в регионах по рейтингу', fontsize=16);

# %%
(region_data.pivot_table(index='rating', values=['na_sales','eu_sales','jp_sales'], aggfunc='sum')
 .sort_values(by='na_sales', ascending=False)
 .plot(kind='bar', figsize=(13,4), fontsize=12, rot=45)
)
plt.title('Продажи в регионах по рейтингу', fontsize=16)
plt.ylabel('Продажи', fontsize=14)
plt.xlabel('Рейтинг', fontsize=14);

# %% [markdown]
# Рейтинг влияет на продажи, в Европе, в Америке, преобладает «M» («Mature») — «Для взрослых»: Материалы игры не подходят для лиц младше 17 лет. Проекты с данным рейтингом могут содержать жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику. И большой пласт игр, у которых нет рейтинга или он не известен  в каждом регионе. В Японии же «E» («Everyone») — «Для всех»: Содержание вполне подходит для всех возрастов (ранее с 6 лет). Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера.

# %% [markdown]
# **Вывод:** Исходя из полученных данных мы не можем составить точный портрет пользователей по региону, т.к большая часть игр не имеет рейтинга. Примерно:
#
# **NA:**: Взрослый игрок, предпочитающий Шутер, Экшен и РПГ на "PS4" и "XOne".
#
# **EU:**: Взрослый игрок, предпочитающий Шутер, Экшен и Спорт на "PS4".
#
# **JP:** Игрок любого возраста, предпочитающий РПГ, Экшен и Шутер на "3DS" и "PS4"'.

# %% [markdown]
# ## Проверка гипотезы

# %% [markdown]
# Поясните:
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# **Нулевая гипотеза:** Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# **Альтернативная гипотеза:** Средние пользовательские рейтинги платформ Xbox One и PC не равны.

# %%
xone = relevant_data.query('platform == "XOne" and user_score != 0')
pc = relevant_data.query('platform == "PC" and user_score != 0')

# %%
sample1 = xone['user_score']
sample2 = pc['user_score']
print(f'среднее первой выборки: {np.mean(sample1)}')
print(f'среднее второй выборки: {np.mean(sample2)}')
alpha = 0.1
results = st.ttest_ind(sample1, sample2)
print('p-значение', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось опровергнуть нулевую гипотезу')
# Out:
# среднее первой выборки: 6.594545454545456
# среднее второй выборки: 6.298360655737705
# p-значение 0.10450507919348415
# Не получилось опровергнуть нулевую гипотезу

# %% [markdown]
# Вывод: использовалась двусторонняя гипотеза для средних двух генеральных совокупностей, которые не зависят друг от друга. Для сравнения были взяты две платформы и их среднии показатели по отзывам пользователей, если показатели равны гипотеза верна, альтернативная гипотеза, что они не равны, одна либо больше или меньше.
#
# Не получилось опровергнуть нулевую гипотезу, есть основание полагать, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые, исходя из этих данных.

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные

# %% [markdown]
# **Нулевая гипотеза:** Средние пользовательские рейтинги жанров Action и Sports одинаковые.
#
# **Альтернативная гипотеза:** Средние пользовательские рейтинги жанров Action и Sports не равны.

# %%
action = relevant_data.query('genre == "Action" and user_score != 0') 
sports = relevant_data.query('genre == "Sports" and user_score != 0')

# %%
sample1 = action['user_score']
sample2 = sports['user_score']
print(f'среднее первой выборки: {np.mean(sample1)}')
print(f'среднее второй выборки: {np.mean(sample2)}')
alpha = 0.05
results = st.ttest_ind(sample1, sample2)
print('p-значение', results.pvalue)
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось опровергнуть нулевую гипотезу')
# Out:
# среднее первой выборки: 6.760606060606061
# среднее второй выборки: 5.2251968503937
# p-значение 2.8711147985105864e-19
# Отвергаем нулевую гипотезу

# %% [markdown]
# Вывод: использовалась двусторонняя гипотеза для средних двух генеральных совокупностей, которые не зависят друг от друга. Для сравнения были взяты две жанра и их среднии показатели по отзывам пользователей, если показатели равны гипотеза верна, альтернативная гипотеза, что они не равны, одна либо больше или меньше.
#
# Отвергаем нулевую гипотезу, да, средние пользовательские рейтинги жанров Action и Sports возможно могут быть не равны, т.е. среднее оценка отзывов у жанра Спорт ниже, чем у Экшена, только полагаясь на малую часть полученных данных.

# %% [markdown]
# ## Общий вывод:

# %% [markdown]
# В ходе проделанной работы было выполнено:
#
# Просмотрена общая информация полученныйх данных , выявлены аномалии и пропущенные значения.
# Проведена подготовка данных: замена названий столбцов, заполнение пропусков, приведение к нужному типу данных и т.д.
# Проведен исследовательский анализ по данным и подготовлены актуальные данные.
# Составлены портреты пользователей для представленных регионов продаж.
# Выполнены проверки гипотез.
# Успешность продажи компьютерных игр зависят от основных составляющих: в каком регионе, кем, на каких платформах и какого она жанра, плюс предварительные отзывы критиков, пользователей.
#
# Конечно же популярные компании это лидеры продаж, которые зарекомендовали себя на рынке и используют свои любимые жанры, накопили аудиторию фанатов, которая обязательно купит их игру. Регион тоже влияет на продажи, ведь в каждой стране свои предпочтения, интересы и устои.
# Платформа определяет технические возможности разработчиков. Здесь есть прямая зависимость: лучше, новее платформа - значит лучше, новее игра. Средний жизненный цикл платформы в 7 лет обусловлен ростом и развитием технологий, ростом населения и сменой трендов.
# Жанр - это то, что выбирает игрок. Каждый человек уникален, и не каждому игроку будет по душе одновременно рпг или шутеры или головоломки. Соответсвенно студии-разработчики и издатели боряться за целевую аудиторию своего продукта.
#
# Рекомендации: делать ставку на современные популярные платформы. Продавать новые игры на PS4, Xbox и 3DS.
# Выставлять на прилавки популярные жанры - экшен, шутеры, рпг и спортивные.
# Следить за аудиторией, их предпочтениями, в основом большинство игр рассчитано на взрослых совершеннолетних игроков. Но не забывать и о младших или игр для любого поколения!
